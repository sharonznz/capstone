# %% [markdown]
# # This notebook downloads and saves as text documents press releases from the 6 New Zealand political parties likely to be represented in Parliament following the September 2017 General Election: National, Labour, NZ First, Greens, Maori Party, and ACT.

# %%
import urllib.request
from urllib.request import urlopen
from bs4 import BeautifulSoup
import os

# %%
def clear_all():
    urls   = []
    titles = []
    all_links = []
    slash_links = []
    releases_pages = []
    return(urls, titles, all_links, slash_links, releases_pages)

def write_to_file(textstr, filename):    
    text = bytes(textstr, 'utf-8')
    file = open(filename,'wb')
    file.write(text)
    file.close()
    return()

# %% [markdown]
# ### 1. Get Labour press releases

# %%
# First scrape press release URLs
all_links = []

# Pages with press release urls on them (13 pages of them from start July):
releases_pages = ['http://www.labour.org.nz/press_releases']
for i in range(2,18):  # (2,18) is all of June, July and August (and into September)
    pg = 'http://www.labour.org.nz/press_releases?page=' + str(i) 
    releases_pages.append(pg)

for each_page in releases_pages:    
    r = urllib.request.urlopen(each_page).read()
    soup = BeautifulSoup(r, "lxml")
    #print(soup.prettify())
    
    mess = soup.find_all('span', class_="read-more")
    for subby in mess:
        links = subby.find_all('a')        
        for link in links:
            relative_url = link.get('href')
            relative_url = relative_url.replace('http://www.labour.org.nz', '') # Fix the occasional absolute url
            new_link = 'http://www.labour.org.nz' + str(relative_url)
            all_links.append(new_link)

print(len(all_links))
#print(all_links)

# %%
def scrape_labour(urls):
    clear_all()
    for newurl in urls:
        print(newurl)    
        filename = newurl[25:] + '.txt'
        full_path = os.path.join('labour', filename)
        if not os.path.exists(full_path):
            page      = urllib.request.urlopen(newurl).read()
            soup      = BeautifulSoup(page, "lxml")
         #   print(soup.prettify())
            reltext   = soup.find('div', class_ = 'content blog-content').get_text()
            if soup.find(class_ = 'byline'):
                relbyline = soup.find(class_ = 'byline').get_text()
            else:
                print('url', newurl, 'has no byline. Add manually.')
                relbyline = 'XXX'
        #     text = str(relbyline) + str(reltext)        # If you want author and date at start use this
            text = str(reltext)        
            write_to_file(text, full_path)
        else:
            continue
    
scrape_labour(all_links)

# %% [markdown]
# ### 2. Get National Party press releases

# %%
clear_all()
slash_links = []
all_links = []

# Pages with press release urls on them:
releases_pages = ['https://www.national.org.nz/press']
for i in range(2,91):  # (2,56) is all of June, July and August and up to Sep 8
    pg = 'https://www.national.org.nz/press?page=' + str(i) 
    releases_pages.append(pg)

for each_page in releases_pages:    
    r = urllib.request.urlopen(each_page).read()
    soup = BeautifulSoup(r, "lxml")
    for link in soup.find_all('a'):
        all_links.append(link.get('href'))
        
for linky in all_links:
    if linky:
        if len(linky)>36:
            if linky[0:36] == 'http://www.facebook.com/share.php?u=':
                slash_links.append(linky[36:])
            else:   
                pass
        else:
            pass
    else:
        pass

print(len(slash_links))
# Out:
# 900

# %%
# Now scrape similarly to before.

def scrape_national(urls):
    counter = 0
    for newurl in urls:
    #    print(newurl)   
        filename = newurl[28:] + '.txt'
        full_path = os.path.join('national', filename)
        if not os.path.exists(full_path):
            page      = urllib.request.urlopen(newurl).read()
            soup      = BeautifulSoup(page, "lxml")
    #        print(soup.prettify())
            reltext   = soup.find('div', class_ = 'content').get_text()
            if soup.find(class_ = 'author'):  # Some press releases are missing an author field
                relauthor = soup.find(class_ = 'author').get_text()
            else:
                print('url', newurl, 'has no author field. May need to add manually.')
                relauthor = 'XXX'        
            if soup.time:  # Some press releases are missing a time field ??
                reldate   = soup.time.get_text()
            else:
                print('url', newurl, 'has no date field. May need to add manually.')
                reldate = ' XXX' 
            text      = str(reltext)
#            text      = str(relauthor) + str(reldate) + ' ' + str(reltext)  # Use this if you want author and time
            write_to_file(text, full_path)
        else:
            continue
        counter += 1
    print(counter,"press releases saved as text documents.")   
    
scrape_national(slash_links)
# Out:
# 365 press releases saved as text documents.

# %% [markdown]
# ### 3. Get NZ First press releases

# %%
clear_all()
all_links = []

# Pages with press release urls on them (47 pages of them for June/July/August):
releases_pages = ['http://www.nzfirst.org.nz/news']
for i in range(2,48):  # (2,48) is all of June, July and August
    pg = 'http://www.nzfirst.org.nz/news?page=' + str(i) 
    releases_pages.append(pg)

for each_page in releases_pages:    
    r = urllib.request.urlopen(each_page).read()
    soup = BeautifulSoup(r, "lxml")
    #print(soup.prettify())
    
    mess = soup.find_all('div', class_="blog-title-wrap")
    for subby in mess:
        messy = subby.find_all('a')
        #print(mess)
        for link in messy:
            relative_url = link.get('href')
            new_link = 'http://www.nzfirst.org.nz' + str(relative_url)
            all_links.append(new_link)

print(len(all_links))
#print(all_links[:44])
# Out:
# 240
# ['http://www.nzfirst.org.nz/tvnz_debate', 'http://www.nzfirst.org.nz/stealing_policies_pretending_they_re_your_own_dishonest', 'http://www.nzfirst.org.nz/promises_made_without_productivity_just_pipe_dreams', 'http://www.nzfirst.org.nz/speech_national_immigration_cowboys_need_reining_in', 'http://www.nzfirst.org.nz/speech_new_zealand_first_working_in_the_best_interest_of_seniors', 'http://www.nzfirst.org.nz/commitment_to_re_establishing_forestry_service', 'http://www.nzfirst.org.nz/immigration_far_worse_than_revealed_over_60_000_not_recorded_as_migrants', 'http://www.nzfirst.org.nz/is_auckland_s_mayor_backtracking_on_port_promises', 'http://www.nzfirst.org.nz/english_makes_miraculous_discovery_northland_exists', 'http://www.nzfirst.org.nz/speech_seriously_alarming_policies_on_water', 'http://www.nzfirst.org.nz/iconic_northland_farm_disappears_into_foreign_hands', 'http://www.nzfirst.org.nz/speech_the_old_parties_are_forgetting_seniors_but_we_aren_t', 'http://www.nzfirst.org.nz/speech_the_regions_are_not_another_country_but_the_future', 'http://www.nzfirst.org.nz/northport_is_northland_s_future_as_much_as_it_is_auckland_s', 'http://www.nzfirst.org.nz/no_surprises_policy_just_breached_by_civil_service_and_national_politicians', 'http://www.nzfirst.org.nz/full_mental_health_inquiry_now_even_more_urgent', 'http://www.nzfirst.org.nz/new_zealand_first_has_vision_to_revitalise_and_future_proofedroof_forestry', 'http://www.nzfirst.org.nz/new_zealand_first_announces_list_for_2017_general_election', 'http://www.nzfirst.org.nz/forestry_crisis_needs_addressing', 'http://www.nzfirst.org.nz/a_mistake_that_was_fixed', 'http://www.nzfirst.org.nz/national_labour_flop_on_affordable_housing', 'http://www.nzfirst.org.nz/national_dishes_out_the_cash_as_auckland_failure_hits_home', 'http://www.nzfirst.org.nz/speech_opening_of_new_buildings_at_tomarata_school', 'http://www.nzfirst.org.nz/tv_election_debates_just_so_old_school', 'http://www.nzfirst.org.nz/nz_first_reiterates_support_for_a_wooden_stadium', 'http://www.nzfirst.org.nz/new_zealand_first_announces_auckland_region_candidates', 'http://www.nzfirst.org.nz/new_zealand_first_policy_on_power_companies', 'http://www.nzfirst.org.nz/rosy_glow_on_the_economy_is_a_sham', 'http://www.nzfirst.org.nz/speech_putting_the_new_zealand_economy_first', 'http://www.nzfirst.org.nz/mt_albert_state_housing_land_now_in_chinese_hands', 'http://www.nzfirst.org.nz/national_s_trade_myopia_sees_japan_slap_tariffs_on_our_beef', 'http://www.nzfirst.org.nz/teachers_can_feel_miffed', 'http://www.nzfirst.org.nz/sanity_needs_to_prevail_over_immigration', 'http://www.nzfirst.org.nz/_desperado_bill_pulling_out_political_bribes', 'http://www.nzfirst.org.nz/_if_you_can_keep_your_head_when_all_about_you_are_losing_theirs', 'http://www.nzfirst.org.nz/two_old_parties_running_scared', 'http://www.nzfirst.org.nz/new_zealand_first_deplores_govt_s_manuka_honey_wrecking_ball', 'http://www.nzfirst.org.nz/100_plus_serious_criminals_walking_free_is_not_justice', 'http://www.nzfirst.org.nz/housing_crisis_a_farce_of_pot_calling_kettle_black', 'http://www.nzfirst.org.nz/mangawhai_rates_quashed_but_no_order_for_refunds', 'http://www.nzfirst.org.nz/sir_colin_meads', 'http://www.nzfirst.org.nz/national_government_wimps_out_to_giant_multi_nationals', 'http://www.nzfirst.org.nz/nz_first_commits_to_raising_minimum_wage_to_20_an_hour', 'http://www.nzfirst.org.nz/speech_getting_nz_out_of_struggle_street_new_zealand_first_announces_bay_of_plenty_coromandel_and_east_coast_candidates_for_2017_general_election']

# %%
# Now scrape similarly to before.
''
def scrape_nzfirst(urls):
    counter = 0
    for newurl in urls:
        print(newurl)
        try:
            page = urllib.request.urlopen(newurl).read()
        except urllib.error.URLError:
            print ("Page not found!")    
            continue
        filename = newurl[26:] + '.txt'
        full_path = os.path.join('nzfirst', filename)
        if not os.path.exists(full_path):
            soup      = BeautifulSoup(page, "lxml")
      #      print(soup.prettify())
            if soup.find('div', class_ = 'content wysiwyg'):
                reltext = soup.find('div', class_ = "content wysiwyg")
            else:
                print("for url ", url, "I cannot find class content wysiwyg")
            if soup.find(class_ = 'page-tag'):  
                relauthor = soup.find(class_ = 'page-tag').get_text()
            else:
                print('url', newurl, 'has no author field. May need to add manually.')
                relauthor = 'unauthored '        
            if soup.find('div', class_ = 'meta').get_text():               
                reldate   = soup.find('div',class_ = 'meta').get_text()
            else:
                print('url', newurl, 'has no date field. Add manually.')
                reldate = ' XXX' 
    #         text      = str(relauthor) + str(reldate) + ' ' + reltext.get_text() # Use this if you want author and date
            text      = reltext.get_text()

            write_to_file(text, full_path)
            counter += 1
    print(counter,"NZ First press releases saved as text documents.")   
    
scrape_nzfirst(all_links)
# Out:
# http://www.nzfirst.org.nz/tvnz_debate
# http://www.nzfirst.org.nz/stealing_policies_pretending_they_re_your_own_dishonest
# http://www.nzfirst.org.nz/promises_made_without_productivity_just_pipe_dreams
# http://www.nzfirst.org.nz/speech_national_immigration_cowboys_need_reining_in
# http://www.nzfirst.org.nz/speech_new_zealand_first_working_in_the_best_interest_of_seniors
# http://www.nzfirst.org.nz/commitment_to_re_establishing_forestry_service
# http://www.nzfirst.org.nz/immigration_far_worse_than_revealed_over_60_000_not_recorded_as_migrants
# http://www.nzfirst.org.nz/is_auckland_s_mayor_backtracking_on_port_promises
# http://www.nzfirst.org.nz/english_makes_miraculous_discovery_northland_exists
# http://www.nzfirst.org.nz/speech_seriously_alarming_policies_on_water
# url http://www.nzfirst.org.nz/speech_seriously_alarming_policies_on_water has no author field. May need to add manually.
# http://www.nzfirst.org.nz/iconic_northland_farm_disappears_into_foreign_hands
# http://www.nzfirst.org.nz/speech_the_old_parties_are_forgetting_seniors_but_we_aren_t
# http://www.nzfirst.org.nz/speech_the_regions_are_not_another_country_but_the_future
# http://www.nzfirst.org.nz/northport_is_northland_s_future_as_much_as_it_is_auckland_s
# http://www.nzfirst.org.nz/no_surprises_policy_just_breached_by_civil_service_and_national_politicians
# http://www.nzfirst.org.nz/full_mental_health_inquiry_now_even_more_urgent
# http://www.nzfirst.org.nz/new_zealand_first_has_vision_to_revitalise_and_future_proofedroof_forestry
# http://www.nzfirst.org.nz/new_zealand_first_announces_list_for_2017_general_election
# http://www.nzfirst.org.nz/forestry_crisis_needs_addressing
# http://www.nzfirst.org.nz/a_mistake_that_was_fixed
# http://www.nzfirst.org.nz/national_labour_flop_on_affordable_housing
# http://www.nzfirst.org.nz/national_dishes_out_the_cash_as_auckland_failure_hits_home
# http://www.nzfirst.org.nz/speech_opening_of_new_buildings_at_tomarata_school
# http://www.nzfirst.org.nz/tv_election_debates_just_so_old_school
# http://www.nzfirst.org.nz/nz_first_reiterates_support_for_a_wooden_stadium
# http://www.nzfirst.org.nz/new_zealand_first_announces_auckland_region_candidates
# http://www.nzfirst.org.nz/new_zealand_first_policy_on_power_companies
# http://www.nzfirst.org.nz/rosy_glow_on_the_economy_is_a_sham
# http://www.nzfirst.org.nz/speech_putting_the_new_zealand_economy_first
# http://www.nzfirst.org.nz/mt_albert_state_housing_land_now_in_chinese_hands
# http://www.nzfirst.org.nz/national_s_trade_myopia_sees_japan_slap_tariffs_on_our_beef
# http://www.nzfirst.org.nz/teachers_can_feel_miffed
# http://www.nzfirst.org.nz/sanity_needs_to_prevail_over_immigration
# http://www.nzfirst.org.nz/_desperado_bill_pulling_out_political_bribes
# http://www.nzfirst.org.nz/_if_you_can_keep_your_head_when_all_about_you_are_losing_theirs
# http://www.nzfirst.org.nz/two_old_parties_running_scared
# http://www.nzfirst.org.nz/new_zealand_first_deplores_govt_s_manuka_honey_wrecking_ball
# http://www.nzfirst.org.nz/100_plus_serious_criminals_walking_free_is_not_justice
# http://www.nzfirst.org.nz/housing_crisis_a_farce_of_pot_calling_kettle_black
# http://www.nzfirst.org.nz/mangawhai_rates_quashed_but_no_order_for_refunds
# http://www.nzfirst.org.nz/sir_colin_meads
# http://www.nzfirst.org.nz/national_government_wimps_out_to_giant_multi_nationals
# http://www.nzfirst.org.nz/nz_first_commits_to_raising_minimum_wage_to_20_an_hour
# http://www.nzfirst.org.nz/speech_getting_nz_out_of_struggle_street_new_zealand_first_announces_bay_of_plenty_coromandel_and_east_coast_candidates_for_2017_general_election
# http://www.nzfirst.org.nz/new_zealand_customs_proves_war_dogs_bill_unnecessary
# http://www.nzfirst.org.nz/national_scheming_to_lock_in_tppa_so_future_govt_has_no_influence
# http://www.nzfirst.org.nz/statisticsnz_confirms_economy_treading_water
# http://www.nzfirst.org.nz/nz_first_giving_priority_to_penlink_and_hill_street
# http://www.nzfirst.org.nz/immigration_favoured_baby_boomers_abandoned_to_their_pain
# http://www.nzfirst.org.nz/national_and_mpi_need_to_up_their_biosecurity_game
# http://www.nzfirst.org.nz/national_too_slow_out_of_gates_over_nz_racing_industry_crisis
# http://www.nzfirst.org.nz/taxpayers_spent_70_million_with_fraud_hit
# http://www.nzfirst.org.nz/new_zealand_first_announces_canterbury_candidates
# http://www.nzfirst.org.nz/speech_transition_to_a_better_future_multi_purpose_stadium
# http://www.nzfirst.org.nz/multiple_national_mp_s_criticise_bootcamp_training_programmes
# http://www.nzfirst.org.nz/labour_and_labor_collusion_over_barnaby_joyce_grows
# http://www.nzfirst.org.nz/barnaby_joyce_hit_an_underarm_delivery
# http://www.nzfirst.org.nz/new_zealand_first_announces_wellington_region_candidates
# http://www.nzfirst.org.nz/national_backs_race_based_water_taxes_had_enough
# http://www.nzfirst.org.nz/daggers_being_worn_in_public_not_for_new_zealand
# http://www.nzfirst.org.nz/another_u_turn_by_national_on_youth_crime
# http://www.nzfirst.org.nz/nz_wood_processing_under_threat_from_lack_of_action
# http://www.nzfirst.org.nz/dog_whistling_about_boot_camps_bit_late_for_national
# http://www.nzfirst.org.nz/new_zealand_first_will_make_the_government_s_fleet_100_zero_emissions_by_2025_26
# url http://www.nzfirst.org.nz/new_zealand_first_will_make_the_government_s_fleet_100_zero_emissions_by_2025_26 has no author field. May need to add manually.
# http://www.nzfirst.org.nz/national_writes_blank_cheques_while_labour_taxes_had_enough
# http://www.nzfirst.org.nz/talking_northland_and_making_up_the_facts
# http://www.nzfirst.org.nz/time_to_put_rescue_choppers_on_sounder_financial_footing
# http://www.nzfirst.org.nz/national_sidesteps_education_funding_crisis_again
# http://www.nzfirst.org.nz/labour_s_water_tax_a_food_tax
# http://www.nzfirst.org.nz/nz_first_s_student_driving_policy_a_winner
# http://www.nzfirst.org.nzhttp://www.scoop.co.nz/stories/ED1708/S00035/school-driving-lessons-benefit-students-in-many-ways.htm
# Page not found!
# http://www.nzfirst.org.nz/brynderwyns_upgrade_secrets_and_tall_stories
# http://www.nzfirst.org.nz/national_so_close_to_greens_they_were_siamese_twins
# http://www.nzfirst.org.nz/country_saved_from_national_s_loony_animal_manure_imports
# http://www.nzfirst.org.nz/economic_circumstances_can_change_suddenly
# http://www.nzfirst.org.nz/labour_s
# http://www.nzfirst.org.nz/ditch_hosking_now
# http://www.nzfirst.org.nz/health_minister_s_top_priority_all_talk_no_action
# http://www.nzfirst.org.nz/labour_s_rip_off_water_policy_mindless
# http://www.nzfirst.org.nz/cases_of_foreign_student_fraud_just_tip_of_iceberg
# http://www.nzfirst.org.nz/facts_blow_holes_in_pm_s_i_know_nothing
# http://www.nzfirst.org.nz/chance_for_north_rodney_to_leave_hide_s_super_city_disaster
# http://www.nzfirst.org.nz/flattered_by_labour_s_adoption_of_water_policy
# http://www.nzfirst.org.nz/national_building_economy_on_fraud_and_corruption
# http://www.nzfirst.org.nz/if_korean_mud_was_bad_is_animal_excrement_okay
# http://www.nzfirst.org.nz/coleman_denies_issue_with_surgical_mesh
# http://www.nzfirst.org.nz/national_eyes_dollars_only_too_bad_about_mr_big
# http://www.nzfirst.org.nzhttp://www.radionz.co.nz/news/national/336615/old-boys-network-suspected-in-indian-student-market
# Page not found!
# http://www.nzfirst.org.nz/no_common_sense_in_auckland_transport_announcements
# http://www.nzfirst.org.nz/landcorp_challenged_to_go_open_book_on_jericho_station_purchase
# http://www.nzfirst.org.nz/big_spending_national_throws_out_the_election_lollies
# http://www.nzfirst.org.nz/speaker_repeatedly_offends_over_decision_on_auditor_general
# http://www.nzfirst.org.nz/chinese_favoured_ahead_of_southland_local_for_just_200_000
# http://www.nzfirst.org.nz/mp_prison_visits_impeded_by_minister
# http://www.nzfirst.org.nz/auditor_general_goes_but_accountability_paramount
# http://www.nzfirst.org.nz/national_backs_water_royalties_for_some
# http://www.nzfirst.org.nz/pm_all_at_sea_on_dealing_with_housing_crisis
# http://www.nzfirst.org.nz/biosecurity_a_sick_cow_under_nathan_guy
# http://www.nzfirst.org.nz/closures_undermine_police_presence_in_21_communities
# http://www.nzfirst.org.nz/speech_nz_first_restoring_fairness_for_taumarunui_and_provincial_nz
# http://www.nzfirst.org.nz/woodhouse_doing_his_best_to_hide_a_scandal
# http://www.nzfirst.org.nz/pm_s_stuck_record_on_barclay_wearing_thin
# http://www.nzfirst.org.nz/politics_is_a_tough_business
# http://www.nzfirst.org.nz/incomptent_oio_approves_sale_commerce_commission_rejects
# http://www.nzfirst.org.nz/education_minister_s_landmark_decision_on_funding_raises_concerns
# http://www.nzfirst.org.nz/govt_misleads_parliament_and_public_over_house_building
# url http://www.nzfirst.org.nz/govt_misleads_parliament_and_public_over_house_building has no author field. May need to add manually.
# http://www.nzfirst.org.nz/flagship_auckland_social_housing_already_78_per_cent_behind_schedule
# http://www.nzfirst.org.nz/will_dean_hamilton_get_a_silver_fern_farms_golden_parachute_if_so_why
# http://www.nzfirst.org.nz/illegal_firearms_have_police_stretched_especially_in_northland
# http://www.nzfirst.org.nz/parliamentary_commissioner_confirms_wisdom_of_nz_first_s_policy
# http://www.nzfirst.org.nz/mpi_minister_needs_to_pull_finger_on_mycoplasma_bovis
# http://www.nzfirst.org.nz/udc_finance_s_chinese_sale_built_on_a_house_of_renminbi
# http://www.nzfirst.org.nz/tourism_gst_should_be_used_to_help_regional_new_zealand
# http://www.nzfirst.org.nzhttp://www.newshub.co.nz/home/new-zealand/2017/07/what-s-the-future-of-our-regional-airports.html
# Page not found!
# http://www.nzfirst.org.nz/work_visa_record_an_attack_on_young_new_zealanders
# http://www.nzfirst.org.nzhttp://www.radionz.co.nz/news/national/335811/work-visas-hit-all-time-high
# Page not found!
# http://www.nzfirst.org.nz/minister_s_lack_of_concern_for_coromandel_road_appalling
# http://www.nzfirst.org.nz/leak_reveals_national_plans_to_privatise_transpower
# http://www.nzfirst.org.nz/government_thumbs_its_nose_at_primary_health
# http://www.nzfirst.org.nz/nz_first_labels_fujixerox_suspension_window_dressing
# http://www.nzfirst.org.nz/new_zealand_first_fighting_separatism_by_stealth
# http://www.nzfirst.org.nz/mycoplasmaplasma_bovis_outbreak_an_act_of_god_or_act_of_guy
# http://www.nzfirst.org.nz/national_s_promised_highways_bridges_coming_to_nothing
# http://www.nzfirst.org.nz/barclay_squirms_as_english_dodges_yet_again
# http://www.nzfirst.org.nz/speech_bro_cal_government_what_future_with_separatist_local_government
# http://www.nzfirst.org.nz/rsa_sting_does_police_reputation_more_harm_than_good
# http://www.nzfirst.org.nz/national_s_desperation_in_new_but_old_crown_building_company
# http://www.nzfirst.org.nz/manawatu_gorge_and_sh3_are_real_roads_of_national_significance
# http://www.nzfirst.org.nz/national_can_t_hide_impact_of_mass_immigration
# http://www.nzfirst.org.nz/speech_rt_hon_winston_peters_and_dargaville_grey_power
# http://www.nzfirst.org.nz/new_zealand_first_releases_new_information_on_the_joanne_harrison_affair
# http://www.nzfirst.org.nz/whistleblowers_deserve_compensation
# http://www.nzfirst.org.nz/law_change_makes_wairarapa_councils_amalgamation_undemocratic
# http://www.nzfirst.org.nzhttp://www.lgc.govt.nz/the-reorganisation-process/wairarapa-final-proposal/
# Page not found!
# http://www.nzfirst.org.nz/referendum_on_maori_seats
# http://www.nzfirst.org.nz/only_one_party_can_be_trusted_on_nz_super
# http://www.nzfirst.org.nz/quad_bikes_become_the_latest_academic_bogeyman
# http://www.nzfirst.org.nz/govt_putting_politics_ahead_of_suicide_crisis
# http://www.nzfirst.org.nz/convention_speech_the_battle_for_new_zealand
# http://www.nzfirst.org.nz/pro_immigration_scaremongering_rams_up
# http://www.nzfirst.org.nz/we_re_challenging_you_to_an_immigration_debate
# http://www.nzfirst.org.nz/speech_no_room_for_mild_acceptance_let_wellington_know_what_you_think
# http://www.nzfirst.org.nz/national_s_bridges_doesn_t_build_bridges_to_west_coast_miners
# http://www.nzfirst.org.nz/fonterra_catches_the_maori_separatism_bug
# http://www.nzfirst.org.nz/the_bay_wants_change_we_ve_struck_a_chord_with_voters
# http://www.nzfirst.org.nz/pm_dreams_up_jobs_project_as_election_bell_tolls
# http://www.nzfirst.org.nz/time_to_throw_book_at_young_offenders
# http://www.nzfirst.org.nz/speech_campaign_for_the_regions_tour_taupo
# http://www.nzfirst.org.nz/speech_highest_unemployment_region_misrepresents_hawke_s_bay_potential
# http://www.nzfirst.org.nz/audit_office_180_degree_turn_around_on_fujixerox_new_zealand_welcomed
# http://www.nzfirst.org.nz/loose_change_for_te_puea_from_a_government_failing_on_housing
# http://www.nzfirst.org.nz/billion_dollar_wish_list_won_t_fool_anyone
# http://www.nzfirst.org.nz/new_zealand_first_to_put_wool_carpets_back_on_the_floors_of_government
# http://www.nzfirst.org.nz/speech_southland_should_be_nz_s_wealthiest_region
# http://www.nzfirst.org.nz/speech_clutha_southland_getting_a_raw_deal_under_national
# http://www.nzfirst.org.nz/speech_calling_the_greens_out_on_allegations_of_racism
# http://www.nzfirst.org.nz/warning_to_greens_don_t_call_us_racist
# http://www.nzfirst.org.nz/speech_decision_makers_too_remote_but_it_can_be_much_better
# http://www.nzfirst.org.nz/speech_you_have_a_right_to_be_proud_but_it_s_not_all_roses_you_re_being_robbed
# http://www.nzfirst.org.nz/national_s_manawatu_gorge_betrayal
# http://www.nzfirst.org.nz/opinion_piece_lions_tour_bring_sport_back_to_the_people_for_society_s_sake
# http://www.nzfirst.org.nz/speech_excerpts_from_hokitika_policies_for_westland_not_wellington
# http://www.nzfirst.org.nz/peters_keel_haus_nbr_s_keall_over_northland_article
# http://www.nzfirst.org.nz/speech_a_fair_go_for_the_coast
# http://www.nzfirst.org.nz/speech_if_you_are_for_the_regions_vote_for_the_regions_another_broken_promise_on_police
# http://www.nzfirst.org.nz/national_s_house_of_cards_collapses_spectacularly_again
# http://www.nzfirst.org.nz/ministers_listened_to_secret_tapes_as_ministers
# http://www.nzfirst.org.nz/govt_a_major_culprit_in_petrol_price_rip_off
# http://www.nzfirst.org.nz/agent_rubs_kiwi_noses_in_it_with_chinese_purchase_post
# http://www.nzfirst.org.nz/pm_s_fund_paid_for_legal_advice_in_barclay_debacle
# http://www.nzfirst.org.nz/mt_white_station_should_be_kept_in_nz_hands
# http://www.nzfirst.org.nz/speech_whanganui_rsa_campaign_for_the_regions_tour
# http://www.nzfirst.org.nz/an_economy_with_the_hand_brake_on
# http://www.nzfirst.org.nz/mpi_shuts_the_gate_well_after_two_biosecurity_horses_have_bolted
# http://www.nzfirst.org.nz/nz_first_says_so_called_cross_party_agreement_on_cathedral_simply_inadequate
# http://www.nzfirst.org.nz/530_000_miss_out_on_proper_insulation_nz_first_to_fix_it
# http://www.nzfirst.org.nz/waikato_regional_council_to_allow_iwi_to_trade_water
# http://www.nzfirst.org.nz/speech_facts_on_super_and_separatism
# http://www.nzfirst.org.nz/speech_let_s_drop_second_best
# http://www.nzfirst.org.nz/speech_a_real_voice_for_whangarei
# http://www.nzfirst.org.nz/campaign_for_the_regions_tour_begins
# http://www.nzfirst.org.nz/shuffling_and_shifty_pm_not_characteristics_of_a_leader
# http://www.nzfirst.org.nz/new_logo_being_rolled_out
# http://www.nzfirst.org.nz/pm_struggles_as_barclay_cover_up_unravels
# http://www.nzfirst.org.nz/america_s_cup_win_a_salute_to_true_grit
# http://www.nzfirst.org.nz/more_burger_gate_madness_to_come
# http://www.nzfirst.org.nz/speech_national_excelling_only_in_constructing_myths
# http://www.nzfirst.org.nz/national_callously_indifferent_to_tararua_cancer_sufferers
# http://www.nzfirst.org.nz/speech_nz_needs_to_be_careful_to_avoid_a_grenfell_tower_disaster
# http://www.nzfirst.org.nz/kiwis_and_govt_fleeced_in_massive_fuji_xerox_nz_racket
# http://www.nzfirst.org.nz/campaign_for_the_regions_launch_speech
# http://www.nzfirst.org.nz/speech_rose_tinted_glasses_vs_reality
# http://www.nzfirst.org.nz/wholesale_electricity_price_out_of_whack_with_reality
# http://www.nzfirst.org.nz/rt_hon_winston_peters_speech_enough_of_arrogance_and_cover_ups_the_ticking_time_bomb_of_design_and_construction_shortcuts
# http://www.nzfirst.org.nz/waikato_regional_councillor_to_stand_for_nz_first
# http://www.nzfirst.org.nz/farmer_outback_pilot_to_stand_in_rangitikei
# http://www.nzfirst.org.nz/lost_and_found_police_m4_bushmaster_magazine_tip_of_an_iceberg
# http://www.nzfirst.org.nz/playing_dumb_won_t_save_english_over_barclay_debacle
# http://www.nzfirst.org.nz/katie_milne_breaks_the_oldest_ceiling_in_kiwi_farming
# http://www.nzfirst.org.nz/national_blocks_register_of_foreign_land_ownership_again
# http://www.nzfirst.org.nz/national_tone_deaf_to_immigration_disaster
# http://www.nzfirst.org.nz/rt_hon_winston_peters_speech_if_you_want_a_farming_future_you_know_what_to_do
# http://www.nzfirst.org.nz/pm_s_dna_all_over_barclay_debacle_cover_up
# http://www.nzfirst.org.nz/minister_caught_out_on_misleading_water_statement
# http://www.nzfirst.org.nz/pm_ducking_for_cover_on_pike_river_re_entry_but_there_s_a_case_to_answer
# http://www.nzfirst.org.nz/pm_recklessly_ignores_fraud_scandal
# http://www.nzfirst.org.nz/barclay_fiasco_exposes_national_s_low_standards
# http://www.nzfirst.org.nz/the_poor_can_forget_their_greens
# http://www.nzfirst.org.nz/national_killing_rail_slowly
# http://www.nzfirst.org.nz/speech_rt_hon_winston_peters_the_farcical_virtuous_circle_immigration_is_the_economy
# http://www.nzfirst.org.nz/speech_rt_hon_winston_peters_wheels_coming_off_government_spin
# http://www.nzfirst.org.nz/reserve_bank_report_card_shows_why_john_key_resigned
# http://www.nzfirst.org.nz/dodgy_multinationals_get_sweet_266m_deal_from_auckland_ratepayers
# http://www.nzfirst.org.nz/pm_s_pension_portability_bribe_not_fooling_anyone
# http://www.nzfirst.org.nz/minister_s_firearms_inquiry_election_year_back_pedal
# http://www.nzfirst.org.nz/comedy_of_errors_continues_as_crown_manager_re_appointed
# http://www.nzfirst.org.nz/inquiry_needed_into_sfo_incompetence
# http://www.nzfirst.org.nz/new_police_surge_for_whanganui_only_a_trickle
# http://www.nzfirst.org.nz/fujixerox_nz_corruption_scandal_grows_in_spite_of_new_zealand_s_silence
# http://www.nzfirst.org.nz/fujixerox_nz_corruption_blows_out_towards_500m_while_the_establishment_turns_a_blind_eye
# http://www.nzfirst.org.nz/government_dithering_delays_oyster_biosecurity_response
# http://www.nzfirst.org.nz/speech
# http://www.nzfirst.org.nz/national_s_crisis_of_its_own_making
# http://www.nzfirst.org.nz/police_have_struggled_to_pay_their_wage_bill_under_national
# http://www.nzfirst.org.nz/government_mess_up_costs_kaipara_ratepayers_another_321_000
# http://www.nzfirst.org.nz/speech_rt_hon_winston_peters_common_sense_policies_and_they_always_have_been
# http://www.nzfirst.org.nz/parliament_kept_in_dark_over_international_treaties
# http://www.nzfirst.org.nz/falling_short_on_house_building_in_auckland
# http://www.nzfirst.org.nz/no_costings_no_plans_in_northland_bridges_promise
# http://www.nzfirst.org.nz/minister_s_office_interferes_in_kiwirail_decision_making
# http://www.nzfirst.org.nz/3d_printed_milk_no_threat_but_use_of_milk_is
# http://www.nzfirst.org.nz/peters_tells_maori_party_to_stop_tainting_our_policies_with_race
# http://www.nzfirst.org.nz/ministers_gush_but_overlook_game_s_real_value
# http://www.nzfirst.org.nz/greens_greenwash_climate_change_policy_by_stealing_nz_first_s
# http://www.nzfirst.org.nz/rt_hon_winston_peters_speech_small_business_goes_ahead_but_battled_red_tape
# http://www.nzfirst.org.nz/arresting_the_decline_of_native_birds_needs_innovation
# http://www.nzfirst.org.nz/national_s_heart_not_there_to_save_the_birds
# http://www.nzfirst.org.nz/better_education_to_protect_teens_from_sexual_violence
# http://www.nzfirst.org.nz/glib_talk_can_t_mask_reliance_on_immigration
# http://www.nzfirst.org.nz/welcome_to_lions_but_too_few_kiwis_will_see_your_matches_live
# 235 NZ First press releases saved as text documents.

# %% [markdown]
# ### 4. Get Green party press releases

# %%
all_links = []

# Pages with press release urls on them (10 pages of them for June/July/August):
releases_pages = ['https://www.greens.org.nz/media?f[0]=type%3Agreens_press_release']
for i in range(1,11):  # (1,7) is all of July and August
    pg = 'https://www.greens.org.nz/media?page=' + str(i) + '1&f[0]=type%3Agreens_press_release' 
    releases_pages.append(pg)

for each_page in releases_pages:    
    r = urllib.request.urlopen(each_page).read()
    soup = BeautifulSoup(r, "lxml")
  #  print(soup.prettify())
    mess = soup.find_all(class_="field-title")
    for subby in mess:
        messy = subby.find_all('a')
        for link in messy:
            relative_url = link.get('href')
            new_link = 'http://www.greens.org.nz' + str(relative_url)
            all_links.append(new_link)

print(len(all_links))
print(all_links)
# Out:
# 110
# ['http://www.greens.org.nz/news/press-release/green-party-remains-opposed-tpp-11', 'http://www.greens.org.nz/news/press-release/marine-mammals-paying-price-commercial-fishing', 'http://www.greens.org.nz/news/press-release/green-party-launches-plan-pay-women-more', 'http://www.greens.org.nz/news/press-release/punitive-benefit-plan-will-force-more-poverty', 'http://www.greens.org.nz/news/press-release/new-report-confirms-scale-national%E2%80%99s-housing-crisis', 'http://www.greens.org.nz/news/press-release/greens-propose-new-wood-processing-and-manufacturing-regional-research-institute', 'http://www.greens.org.nz/news/press-release/nationals-human-rights-stance-out-touch-and-out-date', 'http://www.greens
        filename = filename.replace('/','') # strip slashes
        filename = filename.replace('%','') # strip %
        filename = filename[20:]
        full_path = os.path.join('green', filename)
        print(newurl)
        try:
            page = urllib.request.urlopen(newurl).read()
        except urllib.error.URLError:
            print ("Page not found!")    
            continue
        soup      = BeautifulSoup(page, "lxml")
       # print(soup.prettify())
        if soup.find('div', class_ = 'field-body'):
            reltext = soup.find('div', class_ = "field-body")
        else:
            print("for url ", newurl, "I cannot find content")
            continue
        if soup.find(class_ = 'field-posted'):  
            relauthor_date = soup.find('div', class_ = 'field-posted').get_text()
        else:
            print('url', newurl, 'has no author-date (field-posted) field. May need to add manually.')
            relauthor_date = 'unauthored '        
#        text      = str(relauthor_date) + ' ' + reltext.get_text()
        text      = reltext.get_text()    # Version without author and date
        
        if not os.path.exists(filename):
            write_to_file(text, full_path)
        else:
            continue
        counter += 1
    print(counter, "Greens press releases saved as text documents.")   
    
scrape_greens(all_links)
# Out:
# http://www.greens.org.nz/news/press-release/green-party-remains-opposed-tpp-11
# http://www.greens.org.nz/news/press-release/marine-mammals-paying-price-commercial-fishing
# http://www.greens.org.nz/news/press-release/green-party-launches-plan-pay-women-more
# http://www.greens.org.nz/news/press-release/punitive-benefit-plan-will-force-more-poverty
# http://www.greens.org.nz/news/press-release/new-report-confirms-scale-national%E2%80%99s-housing-crisis
# http://www.greens.org.nz/news/press-release/greens-propose-new-wood-processing-and-manufacturing-regional-research-institute
# http://www.greens.org.nz/news/press-release/nationals-human-rights-stance-out-touch-and-out-date
# http://www.greens.org.nz/news/press-release/greens-commit-rebuilding-napier-gisborne-rail-line
# http://www.greens.org.nz/news/press-release/new-coastal-hazards-report-reveals-inconvenient-truths-national-led-government
# http://www.greens.org.nz/news/press-release/greens-plan-protect-rivers-and-lakes
# http://www.greens.org.nz/news/press-release/waterfall-funding-destroy-rivers-and-drop-bucket-clean-them
# http://www.greens.org.nz/news/press-release/budget-disappointment-auckland
# http://www.greens.org.nz/news/press-release/national%E2%80%99s-pretence-action-hides-bribe-wealthiest
# http://www.greens.org.nz/news/press-release/revised-tppa-must-come-back-parliament
# http://www.greens.org.nz/news/press-release/national-ignoring-tax-advantages-property-speculation
# http://www.greens.org.nz/news/press-release/green-party%E2%80%99s-new-plan-puts-kiwi-families-first
# http://www.greens.org.nz/news/press-release/silver-fern-farms-closure-reinforces-why-primary-sector-should-stay-nz-hands
# http://www.greens.org.nz/news/press-release/solving-child-poverty-critical-mental-health
# http://www.greens.org.nz/news/press-release/movement-controls-critical-stop-myrtle-rust-spreading
# http://www.greens.org.nz/news/press-release/having-teachers-classrooms-will-need-plan
# http://www.greens.org.nz/news/press-release/govt-action-needed-if-mums-are-be-paid-more
# http://www.greens.org.nz/news/press-release/green-party-supports-accessibility-all
# http://www.greens.org.nz/news/press-release/nick-smith-looks-other-way-environmental-breaches
# http://www.greens.org.nz/news/press-release/green-party-launches-member%E2%80%99s-bill-protect-our-freshwater
# http://www.greens.org.nz/news/press-release/julie-anne-genter-proud-have-worked-people-mt-albert
# http://www.greens.org.nz/news/press-release/government-should-harness-some-all-blacks-pride-environment
# http://www.greens.org.nz/news/press-releases/protect-bees-pesticides-spring
# http://www.greens.org.nz/news/press-releases/john-key-once-again-wrong-refugee-numbers
# http://www.greens.org.nz/news/press-releases/national%E2%80%99s-empty-economic-complacency-failing-today-and-future
# http://www.greens.org.nz/news/press-releases/kiwis-lose-871-million-power-company-privatisations
# http://www.greens.org.nz/news/press-releases/ihumatao-should-be-protected
# http://www.greens.org.nz/news/press-releases/landcorp%E2%80%99s-backing-away-dairy-great-news-environment
# http://www.greens.org.nz/news/press-releases/landcorp%E2%80%99s-%E2%80%98dairy-all-costs%E2%80%99-strategy-not-working
# http://www.greens.org.nz/news/press-releases/greens-prioritise-fixing-health-and-safety-law
# http://www.greens.org.nz/news/press-releases/green-party-bill-will-bring-nz-rental-laws-21st-century
# http://www.greens.org.nz/news/press-releases/greens-vote-against-bad-world-cup-booze-law
# 110 Greens press releases saved as text documents.

# %% [markdown]
# ### 5. Get Maori party press releases

# %%
# Their press releases start on their main page and the urls are ridiculous thereafter

all_links = []

# Pages with press release urls on them (xx pages of them for June/July/August):
releases_pages = ['http://www.maoriparty.org']
for i in range(2,5):  # (2,5) is all of June, July and August and into Sept
    pg = 'http://www.maoriparty.org/?fp=t%2F0pb2vva74axufxqvxziwymplu1c0katfo8mi5qhh3jupuv2btt7auhgr2j5o%2Fnyzsa7ra4dg2ukkxsikmqxg%3D%3D&page=' + str(i) + '&poru=wnycig1t%2Ba24%2Fpnhlfz7yto%2Faklt5encfsqsueywx7hlehvjtjzlv2zerv7z2haa&prvtof=j9ejw%2Falc85a68hgs2xyeg76zfbcphy1bxbsk8ororm%3D' + str(i) 
    releases_pages.append(pg)

for each_page in releases_pages:    
    r = urllib.request.urlopen(each_page).read()
    soup = BeautifulSoup(r, "lxml")
    #print(soup.prettify())
    
    mess = soup.find_all(class_="blog")
    for subby in mess:
        messy = subby.find_all('a')
        for link in messy:
            relative_url = link.get('href')
            new_link = 'http://www.maoriparty.org' + str(relative_url)
            all_links.append(new_link)

all_links = list(set(all_links))      # There is duplication in the list.      
print(len(all_links))
print(all_links)
# Out:
# 48
# ['http://www.maoriparty.org/make_it_wetex', 'http://www.maoriparty.org/labour_in_disarray_over_charter_schools', 'http://www.maoriparty.org/nz_first_is_a_wasted_vote', 'http://www.maoriparty.org/winston_peters_takes_aim_at_m_ori_language', 'http://www.maoriparty.org/maori_party_keeps_its_promise_to_whanau_in_budget_2017', 'http://www.maoriparty.org/poroporoaki_dr_clifford_hamilton_whiting_onz', 'http://www.maoriparty.org/labour_cannot_be_trusted_to_defend_and_protect_m_ori_rights_again', 'http://www.maoriparty.org/mei_reedy_taare_up_for_the_challenge', 'http://www.maoriparty.org/budget_2017_more_tamariki_to_get_kohanga_reo_experience', 'http://www.maoriparty.org/budget_2017_reach_extended_for_wh_nau_ora', 'http://www.maoriparty.org/purpose_skills_and_jobs_are_the_answers_for_pasefika_and_m_ori_youth', 'http://www.maoriparty.org/budget_2017_regions_targeted_in_tourism_push', 'http://www.maoriparty.org/m_ori_party_pays_tribute_to_peter_dunne', 'http://www.maoriparty.org/rahui_papa_status_quo_not_working', 'http://www.maoriparty.org/video_urges_rangatahi_to_open_up', 'http://www.maoriparty.org/m_ori_party_candidate_excited_by_voter_energy', 'http://www.maoriparty.org/biddle_to_stand_for_m_ori_party_in_rotorua', 'http://www.maoriparty.org/taurima_no_to_bootcamps_and_prison', 'http://www.maoriparty.org/m_ori_seats_must_remain_for_the_good_of_m_ori', 'http://www.maoriparty.org/howie_tamati_against_iron_sand_mining', 'http://www.maoriparty.org/putea_i_te_pukoro_advocate_for_a_living_wage_says_te_tai_tonga_candidate_mei_reedy_taare', 'http://www.maoriparty.org/health_of_maori_men_matters_too', 'http://www.maoriparty.org/budget_2017_maori_party_secure_funding_for_maori_landowners', 'http://www.maoriparty.org/poroporoaki_john_te_manihera_chadwick', 'http://www.maoriparty.org/budget_2017_funding_boost_to_keep_te_reo_vibrant', 'http://www.maoriparty.org/maori_party_congratulates_queens_birthday_honours_recipients', 'http://www.maoriparty.org/budget_2017_building_on_m_ori_housing_network_success', 'http://www.maoriparty.org/state_abuse_report_lends_weight_to_call_for_royal_commission_of_inquiry', 'http://www.maoriparty.org/iwirail_launch', 'http://www.maoriparty.org/ill_informed_hosking_needs_to_learn_the_rules', 'http://www.maoriparty.org/our_pacific_dream_and_thank_you_m_ori_party', 'http://www.maoriparty.org/president_message_17daystogo', 'http://www.maoriparty.org/the_fight_for_indigenous_peoples_rights_continue', 'http://www.maoriparty.org/makeitcarrie', 'http://www.maoriparty.org/rahui_papa_supports_our_asian_cousins', 'http://www.maoriparty.org/howie_tamati_backs_the_call_for_inquiry_into_abuse_of_children_in_state_care', 'http://www.maoriparty.org/mullins_a_worthy_inductee_into_nz_business_hall_of_fame', 'http://www.maoriparty.org/m_ori_party_s_howie_tamati_launches_election_campaign', 'http://www.maoriparty.org/mp_proud_to_support_ka_pai_kai_rotorua', 'http://www.maoriparty.org/listen_up_a_youth_voice_on_youth_offending', 'http://www.maoriparty.org/no_kiwi_without_iwi', 'http://www.maoriparty.org/reedy_taare_commends_community_action_against_proposed_integrated_family_health_centre', 'http://www.maoriparty.org/poroporoaki_dame_kahurangi_nganeko_minhinnick', 'http://www.maoriparty.org/poroporoaki_piriniha_prince_ferris', 'http://www.maoriparty.org/m_ori_party_calls_for_royal_commission_of_inquiry_into_child_abuse', 'http://www.maoriparty.org/2017_signs_go_live', 'http://www.maoriparty.org/manurewa_candidate_hohaia_says_let_s_get_legal_on_homelessness', 'http://www.maoriparty.org/tvnz_must_correct_the_lie']

# %%
# Now scrape similarly to before.

def scrape_maori(urls):
    counter = 0
    for newurl in urls: 
        print(newurl)
        filename = newurl[26:] + '.txt'         
        full_path = os.path.join('maori', filename)
        if not os.path.exists(full_path):

            try:
                page = urllib.request.urlopen(newurl).read()
            except urllib.error.URLError:
                print ("Page not found!")    
                continue
            soup      = BeautifulSoup(page, "lxml")
           # print(soup.prettify())
            if soup.find('div', class_ = 'content'):
                reltext = soup.find('div', class_ = "content")
            else:
                print("for url ", url, "I cannot find content")

            text      =  reltext.get_text()

            write_to_file(text, full_path)
        else:
            continue
        counter += 1
    print(counter, "Maori Party press releases saved as text documents.")   
    
scrape_maori(all_links)
# Out:
# http://www.maoriparty.org/make_it_wetex
# http://www.maoriparty.org/labour_in_disarray_over_charter_schools
# http://www.maoriparty.org/nz_first_is_a_wasted_vote
# http://www.maoriparty.org/winston_peters_takes_aim_at_m_ori_language
# http://www.maoriparty.org/maori_party_keeps_its_promise_to_whanau_in_budget_2017
# http://www.maoriparty.org/poroporoaki_dr_clifford_hamilton_whiting_onz
# http://www.maoriparty.org/labour_cannot_be_trusted_to_defend_and_protect_m_ori_rights_again
# http://www.maoriparty.org/mei_reedy_taare_up_for_the_challenge
# http://www.maoriparty.org/budget_2017_more_tamariki_to_get_kohanga_reo_experience
# http://www.maoriparty.org/budget_2017_reach_extended_for_wh_nau_ora
# http://www.maoriparty.org/purpose_skills_and_jobs_are_the_answers_for_pasefika_and_m_ori_youth
# http://www.maoriparty.org/budget_2017_regions_targeted_in_tourism_push
# http://www.maoriparty.org/m_ori_party_pays_tribute_to_peter_dunne
# http://www.maoriparty.org/rahui_papa_status_quo_not_working
# http://www.maoriparty.org/video_urges_rangatahi_to_open_up
# http://www.maoriparty.org/m_ori_party_candidate_excited_by_voter_energy
# http://www.maoriparty.org/biddle_to_stand_for_m_ori_party_in_rotorua
# http://www.maoriparty.org/taurima_no_to_bootcamps_and_prison
# http://www.maoriparty.org/m_ori_seats_must_remain_for_the_good_of_m_ori
# http://www.maoriparty.org/howie_tamati_against_iron_sand_mining
# http://www.maoriparty.org/putea_i_te_pukoro_advocate_for_a_living_wage_says_te_tai_tonga_candidate_mei_reedy_taare
# http://www.maoriparty.org/health_of_maori_men_matters_too
# http://www.maoriparty.org/budget_2017_maori_party_secure_funding_for_maori_landowners
# http://www.maoriparty.org/poroporoaki_john_te_manihera_chadwick
# http://www.maoriparty.org/budget_2017_funding_boost_to_keep_te_reo_vibrant
# http://www.maoriparty.org/maori_party_congratulates_queens_birthday_honours_recipients
# http://www.maoriparty.org/budget_2017_building_on_m_ori_housing_network_success
# http://www.maoriparty.org/state_abuse_report_lends_weight_to_call_for_royal_commission_of_inquiry
# http://www.maoriparty.org/iwirail_launch
# http://www.maoriparty.org/ill_informed_hosking_needs_to_learn_the_rules
# http://www.maoriparty.org/our_pacific_dream_and_thank_you_m_ori_party
# http://www.maoriparty.org/president_message_17daystogo
# http://www.maoriparty.org/the_fight_for_indigenous_peoples_rights_continue
# http://www.maoriparty.org/makeitcarrie
# http://www.maoriparty.org/rahui_papa_supports_our_asian_cousins
# http://www.maoriparty.org/howie_tamati_backs_the_call_for_inquiry_into_abuse_of_children_in_state_care
# http://www.maoriparty.org/mullins_a_worthy_inductee_into_nz_business_hall_of_fame
# http://www.maoriparty.org/m_ori_party_s_howie_tamati_launches_election_campaign
# http://www.maoriparty.org/mp_proud_to_support_ka_pai_kai_rotorua
# http://www.maoriparty.org/listen_up_a_youth_voice_on_youth_offending
# http://www.maoriparty.org/no_kiwi_without_iwi
# http://www.maoriparty.org/reedy_taare_commends_community_action_against_proposed_integrated_family_health_centre
# http://www.maoriparty.org/poroporoaki_dame_kahurangi_nganeko_minhinnick
# http://www.maoriparty.org/poroporoaki_piriniha_prince_ferris
# http://www.maoriparty.org/m_ori_party_calls_for_royal_commission_of_inquiry_into_child_abuse
# http://www.maoriparty.org/2017_signs_go_live
# http://www.maoriparty.org/manurewa_candidate_hohaia_says_let_s_get_legal_on_homelessness
# http://www.maoriparty.org/tvnz_must_correct_the_lie
# 48 Greens press releases saved as text documents.

# %% [markdown]
# ### 6. Get ACT party press releases

# %%
clear_all()

all_links = []
# Pages with press release urls on them (18 pages of them for June/July/August):
releases_pages = ['http://act.org.nz/news'] # 1st page
for i in range(2,27):  # (2,27) is all of June, July and August and into Sep
    pg = 'http://act.org.nz/news/page/' + str(i) + '/' 
    releases_pages.append(pg)

for each_page in releases_pages:    
    r = urllib.request.urlopen(each_page).read()
    soup = BeautifulSoup(r, "lxml")
  #  print(soup.prettify())
    mess = soup.find_all(class_="read-more")
    for subby in mess:
        messy = subby.find_all('a')  # It's a full link, not relative
        for link in messy:
            new_link = link.get('href')
            all_links.append(new_link)

print(len(all_links))
print(all_links)
# Out:
# 130
# ['http://act.org.nz/labours-union-shill-bullies-small-schools/', 'http://act.org.nz/broken-union-model-creating-third-world-staff-shortages/', 'http://act.org.nz/teacher-unions-exploit-school-kids-for-propaganda/', 'http://act.org.nz/national-adopts-acts-planning-policy/', 'http://act.org.nz/act-announces-better-pay-for-great-teachers/', 'http://act.org.nz/education-2/', 'http://act.org.nz/announcement-act-to-level-the-playing-field-for-independent-schools/', 'http://act.org.nz/peters-north-korean-port-plan/', 'http://act.org.nz/biggest-threat-to-childrens-lives-the-housing-shortage/', 'http://act.org.nz/labour-ignores-real-education-problems-and-rolls-out-the-pork-barrel/', 'http://act.org.nz/what-lie-is-shifty-winston-covering-up/', 'http://act.org.nz/was-the-charismatic-crook-going-to-take-his-super-secret-to-the-grave/', 'http://act.org.nz/speech-david-seymour-epsom-campaign-launch/', 'http://act.org.nz/why-wont-peters-front-tomorrow/', 'http://act.org.nz/seymour-responds-to-prime-minister/', 'http://act.org.nz/chicken-peters-refuses-to-front-on-dodgy-policies/', 'http://act.org.nz/if-richard-prosser-is-a-fing-idiot-then-winston-peters-is-a-fing-liar/', 'http://act.org.nz/government-surpluses-no-reason-to-celebrate/', 'http://act.org.nz/seymour-responds-to-resignation-of-dunne/', 'http://act.org.nz/dr-lance-osullivan-joins-ranks-of-end-of-life-choice-supporters/', 'http://act.org.nz/roading-promises-are-worthless-without-act/', 'http://act.org.nz/adams-vs-twyford-both-lose-the-housing-scrap/', 'http://act.org.nz/winstons-minimum-wage-will-kill-northland/', 'http://act.org.nz/housing-crisis-costs-the-average-worker-1000-in-tax/', 'http://act.org.nz/nationals-greatest-failure-a-housing-market-gone-mad/', 'http://act.org.nz/where-do-hipkins-loyalties-lie/', 'http://act.org.nz/sound-bites-v-policy/', 'http://act.org.nz/jacinda-doubles-down-on-labours-xenophobia/', 'http://act.org.nz/free-press-15082017/', 'http://act.org.nz/winstons-racist-attack-against-sikhs-freedom-of-religion/', 'http://act.org.nz/labours-civics-classes-dodgy-dodgy-dodgy/', 'http://act.org.nz/forget-boot-camp-fix-failing-schools/', 'http://act.org.nz/national-are-the-worst-re-offenders-in-youth-crime/', 'http://act.org.nz/poll-proves-joyce-wrong-on-epsom/', 'http://act.org.nz/national-labour-fail-to-show-compassion-on-assisted-dying-leaving-act-as-only-option/', 'http://act.org.nz/attorney-general-busts-myths-on-end-of-life-choice-bill/', 'http://act.org.nz/nationals-inaction-on-water-helps-labour-whack-farmers/', 'http://act.org.nz/seymour-responds-to-the-resignation-of-metiria-turei/', 'http://act.org.nz/epsom-mp-congratulates-police-on-recovery-of-kidnapped-baby/', 'http://act.org.nz/just-how-far-did-metiria-go/', 'http://act.org.nz/what-else-do-david-clendon-and-kennedy-graham-know/', 'http://act.org.nz/james-shaw-signs-greens-death-warrant/', 'http://act.org.nz/jacinda-ardern-out-classed-by-backbench-green-mps/', 'http://act.org.nz/free-press-7082017/', 'http://act.org.nz/act-slams-national-on-housing-consent-failure/', 'http://act.org.nz/own-your-future-new-book-out-now/', 'http://act.org.nz/act-reveals-massive-housing-negligence/', 'http://act.org.nz/jacinda-ardern-fails-first-test-of-leadership/', 'http://act.org.nz/refusal-to-resign-as-mp-is-a-disgrace/', 'http://act.org.nz/jacinda-ardern-must-rule-metiria-turei-out-of-cabinet/', 'http://act.org.nz/metiria-turei-must-resign/', 'http://act.org.nz/act-welcomes-legislation-to-recognise-ridesharing-apps/', 'http://act.org.nz/david-seymour-mourns-passing-of-sir-john-graham/', 'http://act.org.nz/own-your-future-receives-backing-of-stephen-jennings/', 'http://act.org.nz/cost-of-congestion-is-highway-robbery/', 'http://act.org.nz/david-seymour-welcomes-report-of-health-select-committee-on-assisted-dying/', 'http://act.org.nz/epsom-mp-welcomes-action-against-windscreen-washers/', 'http://act.org.nz/littles-resignation-opens-door-for-chaos/', 'http://act.org.nz/business-community-screams-out-for-act-policie ...

# %%
# Now scrape similarly to before.

def scrape_act(urls):
    counter = 0
    for newurl in urls: 
        print(newurl)
        filename = newurl[18:] + '.txt' 
        filename = filename.replace('/','') # strip slashes
        full_path = os.path.join('act', filename)
        if not os.path.exists(full_path):
            try:
                page = urllib.request.urlopen(newurl).read()
            except urllib.error.URLError:
                print ("Page not found!")    
                continue
            soup      = BeautifulSoup(page, "lxml")
            #print(soup.prettify())

            if soup.find('div', class_ = 'entry-content'):
                reltext = soup.find('div', class_ = "entry-content")
                temptext = reltext.get_text()
                temptext = temptext.replace('Facebook0Twitter', '')
            else:
                print("for url ", url, "I cannot find class entry-content")

            if soup.find(class_ = 'fn'):  
                relauthor = soup.find(class_ = 'fn').get_text()
                relauthor = relauthor + ' '
            else:
                print('url', newurl, 'has no author field. May need to add manually.')
                relauthor = 'unauthored '      

            if soup.find('time', class_ = 'updated'):               
                reldate   = soup.find('time', class_ = 'updated').get_text()
            else:
                print('url', newurl, 'has no date field. Add manually.')
                reldate = ' XXX' 
            text      = str(relauthor) + str(reldate) + ' ' + temptext  # Version with date and author
            text      = temptext

            write_to_file(text, full_path)
        else:
            continue
        counter += 1
    print(counter, "ACT press releases saved as text documents.")   
    
scrape_act(all_links)
# Out:
# http://act.org.nz/labours-union-shill-bullies-small-schools/
# http://act.org.nz/broken-union-model-creating-third-world-staff-shortages/
# http://act.org.nz/teacher-unions-exploit-school-kids-for-propaganda/
# http://act.org.nz/national-adopts-acts-planning-policy/
# http://act.org.nz/act-announces-better-pay-for-great-teachers/
# http://act.org.nz/education-2/
# http://act.org.nz/announcement-act-to-level-the-playing-field-for-independent-schools/
# url http://act.org.nz/announcement-act-to-level-the-playing-field-for-independent-schools/ has no author field. May need to add manually.
# url http://act.org.nz/announcement-act-to-level-the-playing-field-for-independent-schools/ has no date field. Add manually.
# http://act.org.nz/peters-north-korean-port-plan/
# http://act.org.nz/biggest-threat-to-childrens-lives-the-housing-shortage/
# http://act.org.nz/labour-ignores-real-education-problems-and-rolls-out-the-pork-barrel/
# http://act.org.nz/what-lie-is-shifty-winston-covering-up/
# http://act.org.nz/was-the-charismatic-crook-going-to-take-his-super-secret-to-the-grave/
# http://act.org.nz/speech-david-seymour-epsom-campaign-launch/
# http://act.org.nz/why-wont-peters-front-tomorrow/
# http://act.org.nz/seymour-responds-to-prime-minister/
# http://act.org.nz/chicken-peters-refuses-to-front-on-dodgy-policies/
# http://act.org.nz/if-richard-prosser-is-a-fing-idiot-then-winston-peters-is-a-fing-liar/
# http://act.org.nz/government-surpluses-no-reason-to-celebrate/
# http://act.org.nz/seymour-responds-to-resignation-of-dunne/
# http://act.org.nz/dr-lance-osullivan-joins-ranks-of-end-of-life-choice-supporters/
# http://act.org.nz/roading-promises-are-worthless-without-act/
# http://act.org.nz/adams-vs-twyford-both-lose-the-housing-scrap/
# http://act.org.nz/winstons-minimum-wage-will-kill-northland/
# http://act.org.nz/housing-crisis-costs-the-average-worker-1000-in-tax/
# http://act.org.nz/nationals-greatest-failure-a-housing-market-gone-mad/
# http://act.org.nz/where-do-hipkins-loyalties-lie/
# http://act.org.nz/sound-bites-v-policy/
# http://act.org.nz/jacinda-doubles-down-on-labours-xenophobia/
# http://act.org.nz/free-press-15082017/
# http://act.org.nz/winstons-racist-attack-against-sikhs-freedom-of-religion/
# http://act.org.nz/labours-civics-classes-dodgy-dodgy-dodgy/
# http://act.org.nz/forget-boot-camp-fix-failing-schools/
# http://act.org.nz/national-are-the-worst-re-offenders-in-youth-crime/
# http://act.org.nz/poll-proves-joyce-wrong-on-epsom/
# http://act.org.nz/national-labour-fail-to-show-compassion-on-assisted-dying-leaving-act-as-only-option/
# http://act.org.nz/attorney-general-busts-myths-on-end-of-life-choice-bill/
# http://act.org.nz/nationals-inaction-on-water-helps-labour-whack-farmers/
